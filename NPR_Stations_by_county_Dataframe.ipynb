# %% [markdown]
# NPR Stations DataFrame by County
# =========
# ---------------
# Create a Dataframe including following columns:
# * FIPS Code
# * County Name
# * State
# * City
# * Station Identifier
# * AM/FM
# * Frequency
# * Twitter Account
#
# ## Import Libraries and configuration files

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.offline as py
import requests
import json
from config import gkey

# %%
#Read CSV and create dataframe
npr_stations_csv = "Public_Radio_Twitter_Handles.csv"
npr_stations_df = pd.read_csv(npr_stations_csv)
npr_stations_df.dtypes
# Out:
# Index                   int64
# State                  object
# City                   object
# Wiki_name              object
# Station Identifier     object
# AM/FM                  object
# Channel Number        float64
# Twitter Handle         object
# Alternate              object
# Twitter                object
# _merge                 object
# Empty_at_load          object
# dtype: object

# %%
npr_stations_df.head()
# Out:
#    Index   State City   Wiki_name Station Identifier AM/FM  Channel Number  \
# 0    702  Alaska  NaN   Anchorage               KNBA    FM            90.3
# 1    703  Alaska  NaN      Juneau               KRNN    FM           102.7
# 2    704  Alaska  NaN      Juneau               KXLL    FM           100.7
# 3    705  Alaska  NaN    Kotzebue               KOTZ    AM           720.0
# 4    706  Alaska  NaN  Sand Point               KSDP    AM           830.0
#
#   Twitter Handle Alternate  Twitter      _merge Empty_at_load
# 0          @KNBA     @aprn  Twitter  right_only   Emptyatload
# 1           None       NaN  Twitter  right_only   Emptyatload
# 2           None       NaN  Twitter  right_only   Emptyatload
# 3           None       NaN  Twitter  right_only   Emptyatload
# 4           None       NaN  Twitter  right_only   Emptyatload

# %%
npr_stations_df = npr_stations_df.loc[npr_stations_df['Twitter Handle'] != 'None']
npr_stations_df.head()
# Out:
#     Index       State City  Wiki_name Station Identifier AM/FM  \
# 0     702      Alaska  NaN  Anchorage               KNBA    FM
# 6     708      Alaska  NaN   Unalaska               KUCB    FM
# 10    712  California  NaN     Angwin               KDFC    FM
# 12    714  California  NaN   Calexico               KQVO    FM
# 13    715  California  NaN  Coachella               KVLA    FM
#
#     Channel Number  Twitter Handle Alternate  Twitter      _merge  \
# 0             90.3           @KNBA     @aprn  Twitter  right_only
# 6             89.7       @KUCBNews       NaN  Twitter  right_only
# 10            89.9  @ClassicalKDFC       NaN  Twitter  right_only
# 12            97.7       @kpbsnews       NaN  Twitter  right_only
# 13            90.3         @kvlatv       NaN  Twitter  right_only
#
#    Empty_at_load
# 0    Emptyatload
# 6    Emptyatload
# 10   Emptyatload
# 12   Emptyatload
# 13   Emptyatload

# %%
for (idx, row) in npr_stations_df.iterrows():
    city = (row.loc['City'])
    wiki = (row.loc['Wiki_name'])
    if (pd.isnull(city)):
        npr_stations_df.at[idx, 'City'] = wiki

# %%
npr_stations_df.head()
# Out:
#     Index       State       City  Wiki_name Station Identifier AM/FM  \
# 0     702      Alaska  Anchorage  Anchorage               KNBA    FM
# 6     708      Alaska   Unalaska   Unalaska               KUCB    FM
# 10    712  California     Angwin     Angwin               KDFC    FM
# 12    714  California   Calexico   Calexico               KQVO    FM
# 13    715  California  Coachella  Coachella               KVLA    FM
#
#     Channel Number  Twitter Handle Alternate  Twitter      _merge  \
# 0             90.3           @KNBA     @aprn  Twitter  right_only
# 6             89.7       @KUCBNews       NaN  Twitter  right_only
# 10            89.9  @ClassicalKDFC       NaN  Twitter  right_only
# 12            97.7       @kpbsnews       NaN  Twitter  right_only
# 13            90.3         @kvlatv       NaN  Twitter  right_only
#
#    Empty_at_load
# 0    Emptyatload
# 6    Emptyatload
# 10   Emptyatload
# 12   Emptyatload
# 13   Emptyatload

# %%
#Save DataFrame to CSV File (Checkpoint)
npr_stations_df.to_csv('npr_stations_cities_in_one_column.csv')

# %%
npr_stations_df = npr_stations_df.drop(['Empty_at_load'], axis=1)
npr_stations_df = npr_stations_df.drop(['Index'], axis=1)
npr_stations_df = npr_stations_df.drop(['Wiki_name'], axis=1)
npr_stations_df = npr_stations_df.drop(['_merge'], axis=1)
npr_stations_df = npr_stations_df.drop(['Twitter'], axis=1)

# %%
npr_stations_df.head()
# Out:
#          State       City Station Identifier AM/FM  Channel Number  \
# 0       Alaska  Anchorage               KNBA    FM            90.3
# 6       Alaska   Unalaska               KUCB    FM            89.7
# 10  California     Angwin               KDFC    FM            89.9
# 12  California   Calexico               KQVO    FM            97.7
# 13  California  Coachella               KVLA    FM            90.3
#
#     Twitter Handle Alternate
# 0            @KNBA     @aprn
# 6        @KUCBNews       NaN
# 10  @ClassicalKDFC       NaN
# 12       @kpbsnews       NaN
# 13         @kvlatv       NaN

# %%
#Variables to be used during data collection
processed = 0
notfound = 0

#Loop to collect Lat/Long for Cities with NPR Stations
for (idx, row) in npr_stations_df.iterrows():
    try:
        #Store current row value for each column
        city = (row.loc['City'])
        state = (row.loc['State'])
        #URL from Google APIs where Lat/Long values will be collected
        query_url = "https://maps.googleapis.com/maps/api/geocode/json?address="+str(city)+","+str(state)+"&key="+str(gkey)
        #JSON request
        response = requests.get(query_url).json()
        #Variables to store lat/long values 
        lat = response["results"][0]["geometry"]["location"]["lat"]
        lng = response["results"][0]["geometry"]["location"]["lng"]
        #Lat/Long columns created and respective values stored in current row
        npr_stations_df.at[idx, 'Latitude'] = lat
        npr_stations_df.at[idx, 'Longitude'] = lng
        #Print to verify data is processing as expected
        print(str(city)+","+str(state)+":"+str(lat)+","+str(lng))
        #Count to validate how many cities have been processed
        processed += 1
    #Error handling if some of the cities are not found
    except:
        #Print to verify when a city is not found
        print("City not found")
        #Count to validate how many cities were not found
        notfound += 1
        continue
#Print to validate final count for both processed and not found cities
print(str(processed)+" cities were processed. "+str(notfound)+" cities were not found.")
# Out:
# Anchorage,Alaska:61.2180556,-149.9002778
# Unalaska,Alaska:53.8844382,-166.5332434
# Angwin,California:38.5757402,-122.4499796
# Calexico,California:32.6789476,-115.4988834
# Coachella,California:33.6803003,-116.173894
# McCloud,California:41.2557119,-122.1394487
# Mojave,California:35.0524699,-118.1739645
# Morro Bay,California:35.3659445,-120.8499924
# Quincy,California:39.9368363,-120.9471764
# Redlands,California:34.0555693,-117.1825381
# Sacramento,California:38.5815719,-121.4943996
# San Ardo,California:36.0205207,-120.9051826
# San Francisco,California:37.7749295,-122.4194155
# Santa Barbara,California:34.4208305,-119.6981901
# Santa Barbara,California:34.4208305,-119.6981901
# Santa Barbara,California:34.4208305,-119.6981901
# Sutter,California:39.1598915,-121.7527482
# Frostburg,Maryland:39.6581424,-78.92835699999999
# 700 cities were processed. 2 cities were not found.

# %%
npr_stations_df.head(10)
# Out:
#         State             City Station Identifier AM/FM  Channel Number  \
# 886   Florida            Tampa               WUSF    FM            89.7
# 887   Florida        Pensacola               WUWF    FM            88.1
# 888   Alabama       Montgomery               WVAS    FM            90.7
# 889  Illinois      Rock Island               WVIK    FM            90.3
# 890   Indiana          Elkhart               WVPE    FM            88.1
# 891  Louisana      New Orleans               WWNO    FM            89.9
# 892  Louisana        Thibodaux               KTLN    FM            90.5
# 893   Florida  West Palm Beach               WXEL    FM            90.7
# 894  Maryland        Baltimore               WYPR    FM            88.1
# 895  Maryland        Frostburg               WFWM    FM            91.9
#
#      Twitter Handle Alternate   Latitude  Longitude
# 886           @wusf       NaN  27.950575 -82.457178
# 887           @wuwf       NaN  30.421309 -87.216915
# 888           @WVAS       NaN  32.366805 -86.299969
# 889         @wvikfm       NaN  41.509477 -90.578748
# 890           @wvpe       NaN  41.681993 -85.976667
# 891           @wwno       NaN  29.951066 -90.071532
# 892           @wwno       NaN  29.795763 -90.822871
# 893         @wxeltv       NaN  26.715342 -80.053375
# 894      @wypr881FM       NaN  39.290385 -76.612189
# 895  @xfsrfrostburg       NaN  39.658142 -78.928357

# %%
#Save DataFrame to CSV File
npr_stations_df.to_csv('npr_stations_by_city.csv')

# %%
#Read CSV and create Dataframe
npr_by_county_csv = 'npr_stations_by_city.csv'
npr_by_county_df = pd.read_csv(npr_by_county_csv)

#URL to get FIPS code
url = 'https://geo.fcc.gov/api/census/block/find?'
#Variables to be used during data collection
processed = 0
notfound = 0

#Loop to add FIPS code and County name to Dataframe
for (idx, row) in npr_by_county_df.iterrows():
    try:
        #Store current row value for each column
        latitude = (row.loc['Latitude'])
        longitude = (row.loc['Longitude'])
        #URL to collect FIPS code and county name
        query_url = str(url)+"&latitude="+str(latitude)+"&longitude="+str(longitude)+"&format=json"
        #JSON Request
        code = requests.get(query_url).json()
        #Variables to store required values (FIPS codes are converted to strings to keep leading zeros in the code)
        county_fips = str(code["County"]["FIPS"]).zfill(5)
        county_name = code["County"]["name"]
        block_fips = str(code["Block"]["FIPS"]).zfill(15)
        #New columns created and values collected from JSON stored in current row 
        npr_by_county_df.at[idx, 'FIPS'] = str(county_fips)
        npr_by_county_df.at[idx, 'County Name'] = county_name
        npr_by_county_df.at[idx, 'FIPS_block'] = str(block_fips)         
        #Count to validate how many records were processed
        processed += 1
        #Print to verify that information is processed
        print(str(county_name)+":"+str(county_fips))
    #Error handling if a location is not found
    except:
        #Print to validate if a location is not found
        print("Location Not Found")
        #Count to validate how many records were not found
        notfound += 1
        pass
#Print to validate final count for both processed and not found locations
print(str(processed)+" locations were processed. "+str(notfound)+" locations were not found.")
# Out:
# Anchorage:02020
# Aleutians West:02016
# Napa:06055
# Imperial:06025
# Riverside:06065
# Siskiyou:06093
# Kern:06029
# San Luis Obispo:06079
# Plumas:06063
# San Bernardino:06071
# Sacramento:06067
# Monterey:06053
# San Francisco:06075
# Santa Barbara:06083
# Santa Barbara:06083
# Santa Barbara:06083
# Sutter:06101
# Ventura:06111
# Essex:25009
# Hillsborough:12057
# Escambia:12033
# Montgomery:01101
# Rock Island:17161
# Elkhart:18039
# Orleans:22071
# Lafourche:22057
# Palm Beach:12099
# Baltimore City:24510
# Allegany:24001
# 700 locations were processed. 2 locations were not found.

# %%
#Show dataframe
npr_by_county_df.head(10)
# Out:
#    Unnamed: 0       State       City Station Identifier AM/FM  Channel Number  \
# 0           0      Alaska  Anchorage               KNBA    FM            90.3
# 1           6      Alaska   Unalaska               KUCB    FM            89.7
# 2          10  California     Angwin               KDFC    FM            89.9
# 3          12  California   Calexico               KQVO    FM            97.7
# 4          13  California  Coachella               KVLA    FM            90.3
# 5          14  California    McCloud               KLDD    FM            91.9
# 6          16  California     Mojave               KCRY    FM            88.1
# 7          17  California  Morro Bay               KESC    FM            99.7
# 8          20  California     Quincy               KQNC    FM            88.1
# 9          21  California   Redlands               KUOR    FM            89.1
#
#    Twitter Handle Alternate   Latitude   Longitude   FIPS      County Name  \
# 0           @KNBA     @aprn  61.218056 -149.900278  02020        Anchorage
# 1       @KUCBNews       NaN  53.884438 -166.533243  02016   Aleutians West
# 2  @ClassicalKDFC       NaN  38.575740 -122.449980  06055             Napa
# 3       @kpbsnews       NaN  32.678948 -115.498883  06025         Imperial
# 4         @kvlatv       NaN  33.680300 -116.173894  06065        Riverside
# 5        @JPRnews       NaN  41.255712 -122.139449  06093         Siskiyou
# 6           @kcrw       NaN  35.052470 -118.173964  06029             Kern
# 7  @classicalkusc       NaN  35.365944 -120.849992  06079  San Luis Obispo
# 8   @capradionews       NaN  39.936836 -120.947176  06063           Plumas
# 9           @scpr       NaN  34.055569 -117.182538  06071   San Bernardino
#
#         FIPS_block
# 0  020200011001015
# 1  020160002001050
# 2  060552017003000
# 3  060250121001006
# 4  060650457071006
# 5  060930012001686
# 6  060290059002066
# 7  060790106031052
# 8  060630001001050
# 9  060710081001016

# %%
#Drop rows with no FIPS 
npr_by_county_df = npr_by_county_df[npr_by_county_df['FIPS'].notnull()]

#Loop to fill leading zeros on FIPS codes
for (idx, row) in npr_by_county_df.iterrows():
    fips_z = (row.loc['FIPS'])
    fips_block_z = (row.loc['FIPS_block'])
    npr_by_county_df.at[idx, 'FIPS'] = str(fips_z).zfill(5)
    npr_by_county_df.at[idx, 'FIPS_block'] = str(fips_block_z).zfill(15)

# %%
#Show row count group by FIPS code
count_fips = npr_by_county_df[['City','FIPS']]
count_fips = count_fips.groupby('FIPS').count()
count_fips = count_fips.rename(columns={'City':'Count'})
count_fips = count_fips.sort_values(by=['Count'], ascending=[False])
count_fips.head(10)
# Out:
#        Count
# FIPS
# 06037      8
# 25001      6
# 41029      5
# 27137      5
# 08031      5
# 27109      4
# 09001      4
# 06083      4
# 36029      4
# 42003      4

# %%
#Reorder dataframe columns
npr_by_county_df = npr_by_county_df[["FIPS", "County Name", "City",  "State", "Latitude", "Longitude", "Station Identifier", "Channel Number", "AM/FM","Twitter Handle","Alternate","FIPS_block"]]
#Sort records by FIPS code
npr_by_county_df = npr_by_county_df.sort_values(by=['FIPS'])

#Show dataframe
npr_by_county_df.head(20)
# Out:
#       FIPS           County Name             City    State   Latitude  \
# 651  01015               Calhoun     Jacksonville  Alabama  33.813713
# 412  01033               Colbert    Muscle Shoals  Alabama  34.744811
# 413  01047                Dallas            Selma  Alabama  32.407359
# 603  01055                Etowah          Gadsden  Alabama  34.014264
# 593  01069               Houston           Dothan  Alabama  31.223231
# 602  01073             Jefferson       Birmingham  Alabama  33.520661
# 639  01089               Madison       Huntsville  Alabama  34.730369
# 652  01089               Madison       Huntsville  Alabama  34.730369
# 635  01097                Mobile           Mobile  Alabama  30.695366
# 694  01101            Montgomery       Montgomery  Alabama  32.366805
# 594  01101            Montgomery  Montgomery/Troy  Alabama  32.376252
# 414  01125            Tuscaloosa       Tuscaloosa  Alabama  33.209841
# 1    02016        Aleutians West         Unalaska   Alaska  53.884438
# 514  02020             Anchorage        Anchorage   Alaska  61.218056
# 0    02020             Anchorage        Anchorage   Alaska  61.218056
# 535  02050                Bethel           Bethel   Alaska  60.792222
# 485  02070            Dillingham       Dillingham   Alaska  59.039722
# 520  02090  Fairbanks North Star        Fairbanks   Alaska  64.837778
# 490  02100                Haines           Haines   Alaska  59.235833
# 519  02110                Juneau           Juneau   Alaska  58.301944
#
#       Longitude Station Identifier  Channel Number AM/FM    Twitter Handle  \
# 651  -85.761354               WLJS            91.9    FM         @WLJS_919
# 412  -87.667529               WQPR            88.7    FM    @Alpublicradio
# 413  -87.021101               WAPR            88.3    FM    @Alpublicradio
# 603  -86.006639               WSGN            91.5    FM          @WBHM903
# 593  -85.390489               WRWA            88.7    FM  @troypublicradio
# 602  -86.802490               WBHM            90.3    FM             @WBHM
# 639  -86.586104               WJAB            90.9    FM          @WJAB-TV
# 652  -86.586104               WLRH            89.3    FM     @WLRH_893FMHD
# 635  -88.039891               WHIL            91.3    FM           @WHILFM
# 694  -86.299969               WVAS            90.7    FM             @WVAS
# 594  -86.310889               WTSU            89.9    FM  @troypublicradio
# 414  -87.569173               WUAL            91.5    FM    @Alpublicradio
# 1   -166.533243               KUCB            89.7    FM         @KUCBNews
# 514 -149.900278               KSKA            91.1    FM             @kska
# 0   -149.900278               KNBA            90.3    FM             @KNBA
# 535 -161.755833               KYUK           640.0    AM         @kyuknews
# 485 -158.457500               KDLG           670.0    AM        @kdlgradio
# 520 -147.716389               KUAC            89.9    FM         @kuacfmtv
# 490 -135.445000               KHNS           102.3    FM          @KHNS_FM
# 519 -134.419722               KTOO           104.3    FM     @KTOOpubmedia
#
#     Alternate       FIPS_block
# 651       NaN  010150021012089
# 412       NaN  010330207042005
# 413       NaN  010479566003019
# 603       NaN  010550012001034
# 593       NaN  010690406001032
# 602       NaN  010730027001097
# 639       NaN  010890031001024
# 652       NaN  010890031001024
# 635       NaN  010970012001266
# 694       NaN  011010015003009
# 594       NaN  011010001001109
# 414       NaN  011250116001038
# 1         NaN  020160002001050
# 514       NaN  020200011001015
# 0       @aprn  020200011001015
# 535       NaN  020500002004040
# 485       NaN  020700002002002
# 520       NaN  020900001001047
# 490       NaN  021000001002040
# 519       NaN  021100005003046

# %%
#Save DataFrame to CSV File
npr_stations_df.to_csv('npr_stations_twitter_by_county.csv')
